# %%
from __future__ import print_function

# %%
import sys
'Python version: %s.%s' % (sys.version_info.major, sys.version_info.minor)
# Out:
# 'Python version: 3.5'

# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import graphviz
import os
from sys import stdout

# %%
print('Requests: %s' % requests.__version__)
print('BeautifulSoup: %s'% bs4.__version__)
print('Pandas: %s'% pd.__version__)
print('Graphviz: %s' % graphviz.__version__)
# %matplotlib inline
# Out:
# Requests: 2.18.4
# BeautifulSoup: 4.5.1
# Pandas: 0.18.1
# Graphviz: 0.8.1

# %% [markdown]
# # How to visualize an XML sitemap using Python
#
# <img src="static/sitemap_graph_2_layer.png" width="700">
#
# A rich sitemap might contain page descriptions and modification dates along with image and video metadata, but the basic purpose of a sitemap is to provide a list the pages on a domain that are accessible to users and web crawlers. In this post, we'll use Python and a toolkit of libraries to parse, categorize, and visualize an XML sitemap. This will involve:
# - extracting the page URLs
# - categorizing URLs by page type
# - plotting a sitemap graph tree
#
# The scripts in this post are compatible with Python 2 and 3 and the library dependencies are Requests and BeautifulSoup4 for extracting the URLs, Pandas for categorization, and Graphviz for creating the visual sitemap. Once you have Python, these libraries can most likely be installed on any operating system with the following terminal commands:
#
# `
# pip install requests
# pip install beautifulsoup4
# pip install pandas
# `
#
# The Graphviz library is more difficult to install. On Mac it can be done with the help of homebrew:
#
# `
# brew install graphviz
# pip install graphviz
# `
#
# For other operating systems or alternate methods, check out the [installation instructions in the documentation](http://graphviz.readthedocs.io/en/latest/manual.html).

# %% [markdown]
# ## Extracting URLs
#
# We'll use the www.sportchek.ca sitemap as an example. It is hosted on their domain and open to the public. Like most large sites, the entire sitemap is split across multiple XML files. These are indexed at the [/sitemap.xml](https://www.sportchek.ca/sitemap.xml) page.
#
# We start by opening the url in Python using requests and then instantiate a "soup" object containing the page content.

# %%
url = 'https://www.ringcentral.com/sitemap.xml'
page = requests.get(url)
print('Loaded page with: %s' % page)

sitemap_index = BeautifulSoup(page.content, 'html.parser')
print('Created %s object' % type(sitemap_index))
# Out:
# Loaded page with: <Response [200]>
# Created <class 'bs4.BeautifulSoup'> object

# %% [markdown]
# Next we can pull the XML sitemap links, which live within the `<loc>` tags.

# %%
sitemap_index.findAll('loc')

# %%
urls = [element.text for element in sitemap_index.findAll('loc')]
urls
# Out:
# ['https://www.ringcentral.com/',
#  'https://www.ringcentral.com/business-phone-system.html',
#  'https://www.ringcentral.com/business-voip.html',
#  'https://www.ringcentral.com/cloud-has-won',
#  'https://www.ringcentral.com/cloud-pbx.html',
#  'https://www.ringcentral.com/collaborative-communications.html',
#  'https://www.ringcentral.com/cpaas.html',
#  'https://www.ringcentral.com/europe',
#  'https://www.ringcentral.com/internet-phone-service.html',
#  'https://www.ringcentral.com/lp/business-voip/small-business-voip.html',
#  'https://www.ringcentral.com/lp/connect.html',
#  'https://www.ringcentral.com/lp/enterprise-communications.html',
#  'https://www.ringcentral.com/lp/gartner-magic-quadrant.html',
#  'https://www.ringcentral.com/lp/rise_of_communications.html',
#  'https://www.ringcentral.com/lp/sip-trunking.html',
#  'https://www.ringcentral.com/lp/small-business-phone-service.html',
#  'https://www.ringcentral.com/lp/synergy-research.html',
#  'https://www.ringcentral.com/multi-line-phone-system.html',
#  'https://www.ringcentral.com/office/business-apps-infographic.html',
#  'https://www.ringcentral.com/office/contact-center-infographic.html',
#  'https://www.ringcentral.com/virtual-phone-service.html',
#  'https://www.ringcentral.com/voip-providers.html',
#  'https://www.ringcentral.com/voip-services.html',
#  'https://www.ringcentral.com/whyringcentral.html',
#  'https://www.ringcentral.com/whyringcentral/analysts.html',
#  'https://www.ringcentral.com/whyringcentral/awards.html',
#  'https://www.ringcentral.com/whyringcentral/awards/awards-2005.html',
#  'https://www.ringcentral.com/whyringcentral/awards/awards-2006.html',
#  'https://www.ringcentral.com/whyringcentral/awards/awards-2007.html',
#  'https://www.ringcentral.com/whyringcentral/awards/awards-2008.html',
#  'https://www.ringcentral.com/whyringcentral/awards/awards-2009.html',
#  'https://www.ringcentral.com/whyringcentral/awards/awards-2010.html',
#  'https://www.ringcentral.com/whyringcentral/awards/awards-2011.html',
#  'https://www.ringcentral.com/whyringcentral/awards/awards-2012.html',
#  'https://www.ringcentral.com/whyringcentral/awards/awards-2013.html',
#  'https://www.ringcentral.com/whyringcentral/awards/awards-2014.html',
#  'https://www.ringcentral.com/whyringcentral/awards/awards-2015.html',
#  'https://www.ringcentral.com/whyringcentral/awards/awards-2016.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/040708.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/24hr-lockouts.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/bactes.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/better-homes-n-gardens.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/binswanger_glass.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/blue_ally.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/blue_health.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/cmms-data.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/construction-monitor.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/corporate-payroll-services-api.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/cresa.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/dalycomputers.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/digital-chalk.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/dmeautomotive.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/ez_surety_bonds.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/firstcreditservices.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/genius-food.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/hawkridge.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/hott-solutions.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/iatric-systems.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/jackson-hewitt.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/john-varvatos.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/medallia.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/midwest-freight.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/motion-recruitment.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/myoutdesk.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/nakedwines.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/open-mortgage.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/rokstar-events.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/santa_clara.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/schoology.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/structural-group.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/synergy.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/travelershaven.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/vigor-systems.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/walker-crips.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/workato.html',
#  'https://www.ringcentral.com/whyringcentral/casestudies/world_vision.html',
#  'https://www.ringcentral.com/whyringcentral/company.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/at-t-extends-reach-with-end-to-end--business-phone-s.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/britons-working-longer-hours-as-customer-expectation.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/cloud-and-saas-industry-veteran-david-t--lee-joins-r.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/cloud-solutions-industry-veteran-walt-weisner-joins-.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/dessange-replaces-on-premise-phone-system-with-ringc.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/employees-cutting-the-corporate-cord--personal-mobil.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/itexpo-miami.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/nakedwines-com-toasts-ringcentral---s-cloud-business.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/ringcentral-announces-pricing-of-initial-public-offe.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/ringcentral-announces-revenue-increase-of-42--for-th.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/ringcentral-appoints-clyde-r--hosein-as-chief-financ.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/ringcentral-cloud-business-phone-solution-wins-best-.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/ringcentral-files-registration-statement-for-propose.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/-ringcentral-for-salesforce-launches-on-salesforce-c.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/ringcentral-honored-as-gold-stevie---award-winner-fo.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/ringcentral-launches-cloud-business-communications-s.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/ringcentral-named-a-top-workplace-by-the-denver-post.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/ringcentral-names-cisco-webex-veteran-david-berman-p.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/ringcentral-office-now-available-on-ingram-micro-clo.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/ringcentral-office-receives-pc-magazine-editors----c.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/ringcentral-optimizes-business-communications-for-by.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/-ringcentral-selected-by-alwayson-as-an-ondemand-top.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/ringcentral-survey-shows-generational-divide.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/ringcentral-to-present-at-ubs-global-technology-conf.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/sandler-partners-becomes-master-agent-for-ringcentra.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/seventy-percent-of-businesses-with-traditional-in-of.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/-sunwarrior-replaces-shoretel-on-premise-phone-syste.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/-synergy-companies-replaces-on-premise-phone-system-.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/truste-scraps-on-premise-phone-system--opts-for-ring.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/tsia-replaces-on-premise-phone-system-with--ringcent.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleasepage/vlad-shmunis-semifinalist-in-northern-california-an-.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2003.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2003/tollfreenumbers.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2004.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2004/localnumbers.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2005.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2005/click-to-call.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2005/onlinefaxing.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2006.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2006/click-to-callme.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2006/click-to-callservice.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2006/click-to-callvoicemail.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2006/faxondemand.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2006/faxservices.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2006/internetfaxpbx.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2006/sendfax.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2006/tollfreeclick-to-call.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2006/tollfreepbx.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2006/tollfreevoicemail.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2006/virtualpbx.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2006/voipfax.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2007.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2007/071107.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2007/110607.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2007/111407.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2007
html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2017/ringcentral-unveils-next-generation-ringcentral-office-.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2017/structural-group-empowers-its-employees-with-ringcentrals-cloud-.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2017/telus-and-ringcentral-expand-portfolio-of-cloud-communications-solutions-to-keep-canadian-businesses-connected.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2017/the-salvation-army-national-headquarters-to-replace-legacy-on-premise-systems-with-ringcentrals-cloud.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2017/tuff-shed-selects-ringcentral-cloud-communications-solutions-to-replace-legacy-systems-serving-130-locations.html',
#  'https://www.ringcentral.com/whyringcentral/company/pressreleases/pressreleases-2017/zane-long--vice-president-of-channel-sales-at-ringcentral--recog.html',
#  'https://www.ringcentral.com/whyringcentral/contactus.html',
#  'https://www.ringcentral.com/whyringcentral/inthenews.html',
#  'https://www.ringcentral.com/whyringcentral/inthenews/inthenews-2007.html',
#  'https://www.ringcentral.com/whyringcentral/inthenews/inthenews-2008.html',
#  'https://www.ringcentral.com/whyringcentral/inthenews/inthenews-2009.html',
#  'https://www.ringcentral.com/whyringcentral/inthenews/inthenews-2010.html',
#  'https://www.ringcentral.com/whyringcentral/inthenews/inthenews-2011.html',
#  'https://www.ringcentral.com/whyringcentral/inthenews/inthenews-2012.html',
#  'https://www.ringcentral.com/whyringcentral/inthenews/inthenews-2013.html',
#  'https://www.ringcentral.com/whyringcentral/inthenews/inthenews-2014.html',
#  'https://www.ringcentral.com/whyringcentral/inthenews/inthenews-2015.html',
#  'https://www.ringcentral.com/whyringcentral/inthenews/inthenews-2016.html',
#  'https://www.ringcentral.com/whyringcentral/leadership.html',
#  'https://www.ringcentral.com/whyringcentral/leadership/clyde-hosein.html',
#  'https://www.ringcentral.com/whyringcentral/leadership/david-sipes.html',
#  'https://www.ringcentral.com/whyringcentral/leadership/derrell-james.html',
#  'https://www.ringcentral.com/whyringcentral/leadership/john-marlow.html',
#  'https://www.ringcentral.com/whyringcentral/leadership/kira-makagon.html',
#  'https://www.ringcentral.com/whyringcentral/leadership/mitesh-dhruv.html',
#  'https://www.ringcentral.com/whyringcentral/leadership/praful-k-shah.html',
#  'https://www.ringcentral.com/whyringcentral/leadership/riadh-dridi.html',
#  'https://www.ringcentral.com/whyringcentral/leadership/richard-borenstein.html',
#  'https://www.ringcentral.com/whyringcentral/leadership/ryan-azus.html',
#  'https://www.ringcentral.com/whyringcentral/leadership/vlad-shmunis.html',
#  'https://www.ringcentral.com/whyringcentral/leadership/vlad-vendrow.html',
#  'https://www.ringcentral.com/whyringcentral/leadership/walt-weisner.html',
#  'https://www.ringcentral.com/whyringcentral/reviews.html',
#  'https://www.ringcentral.com/office/developer-platform.html',
#  'https://www.ringcentral.com/office/features/answering-rules/overview.html',
#  'https://www.ringcentral.com/office/features/auto-attendant/overview.html',
#  'https://www.ringcentral.com/office/features/batch-updates/overview.html',
#  'https://www.ringcentral.com/office/features/box-integration/overview.html',
#  'https://www.ringcentral.com/office/features/business-sms/overview.html',
#  'https://www.ringcentral.com/office/features/caller-id-control/overview.html',
#  'https://www.ringcentral.com/office/features/call-flip/overview.html',
#  'https://www.ringcentral.com/office/features/call-forwarding/overview.html',
#  'https://www.ringcentral.com/office/features/call-logs/overview.html',
#  'https://www.ringcentral.com/office/features/call-metrics-reporting/overview.html',
#  'https://www.ringcentral.com/office/features/call-monitoring/overview.html',
#  'https://www.ringcentral.com/office/features/call-park/overview.html',
#  'https://www.ringcentral.com/office/features/call-recording/overview.html',
#  'https://www.ringcentral.com/office/features/call-screening/overview.html',
#  'https://www.ringcentral.com/office/features/click-to-call/overview.html',
#  'https://www.ringcentral.com/office/features/click-to-call-me/overview.html',
#  'https://www.ringcentral.com/office/features/cloudconnect/overview.html',
#  'https://www.ringcentral.com/office/features/desk-integration/overview.html',
#  'https://www.ringcentral.com/office/features/desktop-apps/overview.html',
#  'https://www.ringcentral.com/office/features/dial-by-name-directory/overview.html',
#  'https://www.ringcentral.com/office/features/directory-listings/overview.html',
#  'https://www.ringcentral.com/office/features/dropbox-integration/overview.html',
#  'https://www.ringcentral.com/office/features/extensions/overview.html',
#  'https://www.ringcentral.com/office/features/global-office-communications/overview.html',
#  'https://www.ringcentral.com/office/features/global-office-communications/solutions.html',
#  'https://www.ringcentral.com/office/features/hot-desking/overview.html',
#  'https://www.ringcentral.com/office/features/intercom-phone-system/overview.html',
#  'https://www.ringcentral.com/office/features/international-phone-numbers/overview.html',
#  'https://www.ringcentral.com/office/features/internet-fax-service/overview.html',
#  'https://www.ringcentral.com/office/features/line-sharing/overview.html',
#  'https://www.ringcentral.com/office/features/message-alerts/overview.html',
#  'https://www.ringcentral.com/office/features/microsoft-pbx-integration/overview.html',
#  'https://www.ringcentral.com/office/features/missed-call-notification/overview.html',
#  'https://www.ringcentral.com/office/features/music-on-hold/overview.html',
#  'https://www.ringcentral.com/office/features/office-365-integration/overview.html',
#  'https://www.ringcentral.com/office/features/okta-active-directory-integration/overview.html',
#  'https://www.ringcentral.com/office/features/online-meetings/audio-conferencing.html',
#  'https://www.ringcentral.com/office/features/online-meetings/overview.html',
#  'https://www.ringcentral.com/office/features/online-meetings/rooms.html',
#  'https://www.ringcentral.com/office/features/online-meetings/video-conferencing.html',
#  'https://www.ringcentral.com/office/features/online-meetings/webinar.html',
#  'https://www.ringcentral.com/office/features/oracle-sales-cloud-integration/overview.html',
#  'https://www.ringcentral.com/office/features/outlook-integration/overview.html',
#  'https://www.ringcentral.com/office/features/presence/overview.html',
#  'https://www.ringcentral.com/office/features/professionally-recorded-greetings/overview.html',
#  'https://www.ringcentral.com/office/features/rcmobile/app_android.html',
#  'https://www.ringcentral.com/office/features/rcmobile/app_iphone.html',
#  'https://www.ringcentral.com/office/features/rcmobile/overview.html',
#  'https://www.ringcentral.com/office/features/ringcentral-for-google/overview.html',
#  'https://www.ringcentral.com/office/features/roles-and-permissions/overview.html',
#  'https://www.ringcentral.com/office/features/salesforce-integration/overview.html',
#  'https://www.ringcentral.com/office/features/servicenow-integration/overview.html',
#  'https://www.ringcentral.com/office/features/single-sign-on/overview.html',
#  'https://www.ringcentral.com/office/features/skype-for-business-integration/overview.html',
#  'https://www.ringcentral.com/office/features/softphone/overview.html',
#  'https://www.ringcentral.com/office/features/toll-free-numbers/overview.html',
#  'https://www.ringcentral.com/office/features/unified-messaging/overview.html',
#  'https://www.ringcentral.com/office/features/virtual-pbx/overview.html',
#  'https://www.ringcentral.com/office/features/visual-voicemail/overview.html',
#  'https://www.ringcentral.com/office/features/voicemail/overview.html',
#  'https://www.ringcentral.com/office/features/voicemail/voicemail-to-email.html',
#  'https://www.ringcentral.com/office/features/voip/overview.html',
#  'https://www.ringcentral.com/office/features/voip-paging/overview.html',
#  'https://www.ringcentral.com/office/features/zendesk-integration/overview.html',
#  'https://www.ringcentral.com/office/how-it-works.html',
#  'https://www.ringcentral.com/office/industry-solutions/business-communications-for-financial-services.html',
#  'https://www.ringcentral.com/office/industry-solutions/construction-businesses-cloud-phone-systems.html',
#  'https://www.ringcentral.com/office/industry-solutions/healthcare-communications-cloud-phone-systems.html',
#  'https://www.ringcentral.com/office/industry-solutions/law-firms-cloud-phone-systems.html',
#  'https://www.ringcentral.com/office/industry-solutions/manufacturing-companies-cloud-phone-systems.html',
#  'https://www.ringcentral.com/office/industry-solutions/overview.html',
#  'https://www.ringcentral.com/office/industry-solutions/professional-services-firms-cloud-phone-systems.html',
#  'https://www.ringcentral.com/office/industry-solutions/real-estate-professionals-cloud-phone-systems.html',
#  'https://www.ringcentral.com/office/industry-solutions/retail-business-cloud-phone-systems.html',
#  'https://www.ringcentral.com/office/industry-solutions/tech-industry-cloud-phone-systems.html',
#  'https://www.ringcentral.com/office/integrations/overview.html',
#  'https://www.ringcentral.com/office/phone-system-faq.html',
#  'https://www.ringcentral.com/office/phone-system-features.html',
#  'https://www.ringcentral.com/office/product-how-it-works.html',
#  'https://www.ringcentral.com/office/voip-phone.html',
#  'https://www.ringcentral.com/contact-center/agents.html',
#  'https://www.ringcentral.com/contact-center/contact-center-features.html',
#  'https://www.ringcentral.com/contact-center/faq.html',
#  'https://www.ringcentral.com/contact-center/integrations.html',
#  'https://www.ringcentral.com/contact-center/overview.html',
#  'https://www.ringcentral.com/contact-center/supervisors.html',
#  'https://www.ringcentral.com/contact-center/workforce-optimization.html',
#  'https://www.ringcentral.com/office/unified-communications.html',
#  'https://www.ringcentral.com/solutions/enterprise-business.html',
#  'https://www.ringcentral.com/solutions/mid-sized-business.html',
#  'https://www.ringcentral.com/solutions/professional-services.html',
#  'https://www.ringcentral.com/solutions/small-business.html',
#  'https://www.ringcentral.com/teams/overview.html',
#  'https://www.ringcentral.com/technology/integrations-apis.html',
#  'https://www.ringcentral.com/technology/overview.html',
#  'https://www.ringcentral.com/technology/qos.html',
#  'https://www.ringcentral.com/technology/reliability.html',
#  'https://www.ringcentral.com/technology/security.html',
#  'https://www.ringcentral.com/technology/user-experience.html',
#  'https://www.ringcentral.com/contact-center/plans-and-pricing.html',
#  'https://www.ringcentral.com/fax/features.html',
#  'https://www.ringcentral.com/fax/features/faq.html',
#  'https://www.ringcentral.com/fax/features/how-it-works.html',
#  'https://www.ringcentral.com/fax/features/whitepaper.html',
#  'https://www.ringcentral.com/office/plansandpricing.html',
#  'https://www.ringcentral.com/partner/agent.html',
#  'https://www.ringcentral.com/partner/agentform.html',
#  'https://www.ringcentral.com/partner/alliance_partners.html',
#  'https://www.ringcentral.com/partner/franchise.html',
#  'https://www.ringcentral.com/partner/franchisor_application.html',
#  'https://www.ringcentral.com/partner/isvreseller.html',
#  'https://www.ringcentral.com/partner/overview.html',
#  'https://www.ringcentral.com/plansandpricing/ringcentralfax.html',
#  'https://www.ringcentral.com/pro/features.html',
#  'https://www.ringcentral.com/pro/features/faq.html',
#  'https://www.ringcentral.com/pro/plansandpricing.html',
#  'https://www.ringcentral.com/company/careers/internship-program.html',
#  'https://www.ringcentral.com/company/careers/job-listings.html',
#  'https://www.ringcentral.com/company/careers/locations.html',
#  'https://www.ringcentral.com/company/careers/overview.html',
#  'https://www.ringcentral.com/whyringcentral/formedia.html',
#  'https://www.ringcentral.com/whyringcentral/pressimages.html',
#  'https://www.ringcentral.com/community/index.html',
#  'https://www.ringcentral.com/demo.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-202.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-213.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-267.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-281.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-302.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-310.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-330.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-347.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-404.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-425.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-510.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-512.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-630.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-646.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-703.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-732.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-805.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-817.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-818.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-916.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-925.html',
#  'https://www.ringcentral.com/features/local-numbers/area-code-949.html',
#  'https://www.ringcentral.com/feedback/sales-contact.html',
#  'https://www.ringcentral.com/legal.html',
#  'https://www.ringcentral.com/legal/apilitos.html',
#  'https://www.ringcentral.com/legal/cc-eulatos.html',
#  'https://www.ringcentral.com/legal/emergency-services.html',
#  'https://www.ringcentral.com/legal/eulatos.html',
#  'https://www.ringcentral.com/legal/hardware-tos.html',
#  'https://www.ringcentral.com/legal/lease-rental.html',
#  'https://www.ringcentral.com/legal/other_licenses/gips_ilbc.html',
#  'https://www.ringcentral.com/legal/other_licenses/json-framework.html',
#  'https://www.ringcentral.com/legal/patents.html',
#  'https://www.ringcentral.com/legal/policies/data-request-guidelines.html',
#  'https://www.ringcentral.com/legal/policies/esignatures.html',
#  'https://www.ringcentral.com/legal/policies/porting.html',
#  'https://www.ringcentral.com/legal/privacy-notice.html',
#  'https://www.ringcentral.com/legal/privacy-shield-notice.html',
#  'https://www.ringcentral.com/legal/ringcentral-hardware-terms-conditions.html',
#  'https://www.ringcentral.com/legal/sdklicense.html',
#  'https://www.ringcentral.com/legal/taxes-and-fees/911.html',
#  'https://www.ringcentral.com/legal/taxes-and-fees/e911.html',
#  'https://www.ringcentral.com/legal/taxes-and-fees/states-and-local.html',
#  'https://www.ringcentral.com/legal/taxes-and-fees/taxes-and-compliance.html',
#  'https://www.ringcentral.com/legal/taxes-and-fees/usf.html',
#  'https://www.ringcentral.com/legal/tou.html',
#  'https://www.ringcentral.com/legal/westcon-terms-conditions.html',
#  'https://www.ringcentral.com/office/features/local-numbers/overview.html',
#  'https://www.ringcentral.com/office/platform/overview.html',
#  'https://www.ringcentral.com/support/capacity.html',
#  'https://www.ringcentral.com/support/international-rates.html',
#  'https://www.ringcentral.com/support/multi-port-ata-spa8000.html',
#  'https://www.ringcentral.com/support/qos.html',
#  'https://www.ringcentral.com/support/qos-information.html',
#  'https://www.ringcentral.com/support/qos-router.html',
#  'https://www.ringcentral.com/office/comparison.html',
#  'https://www.ringcentral.com/office/roi-calculator/index.html',
#  'https://www.ringcentral.com/sitemap.html']

# %% [markdown]
# With some investigation of the XML format for each file above, we again see that URLs can be identified by searching for `<loc>` tags. These URLs can be extracted the same as the XML links were from the index. We loop over the XML documents, appending all sitemap URLs to a list.

# %%
% % time
print("start")
def extract_links(url):
    ''' Open an XML sitemap and find content wrapped in <loc> tags. '''

    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    links = [element.text for element in soup.findAll('loc')]

    return links

sitemap_urls = []
i = 0
for url in urls:
    if i % 100 == 0:
        print(i)
    links = extract_links(url)
    sitemap_urls += links
    i += 1
# Out:
# start
# 0
# 100
# 200
# 300
# 400
# 500
# Wall time: 12min 1s

# %%
'Found {:,} URLs in the sitemap'.format(len(urls))
os.getcwd()
# Out:
# 'C:\\workspace\\sitemap-visualization-tool'

# %% [markdown]
# Let's write these to a file that can be opened in Excel.

# %%
with open('sitemap_urls.dat', 'w') as f:
    for url in urls:
        f.write(url + '\n')

# %% [markdown]
# ## Categorization

# %% [markdown]
# Let's start by loading in the URLs we wrote to a file.

# %%
sitemap_urls = open('sitemap_urls.dat', 'r').read().splitlines()
print('Loaded {:,} URLs'.format(len(sitemap_urls)))
# Out:
# Loaded 584 URLs

# %% [markdown]
# Site-specific categorization such as identifying display listing pages and product pages can be done by applying filters over the URL list. Python is great for this because filters can be very detailed and chained together, plus your results can be reproduced by simply running the script!
#
# On the other hand, we could take a different approach and - instead of filtering for specific URLs - apply an automated algorithm to peel back our sites layers and find the general structure.

# %%
def peel_layers(urls, layers=3):
    ''' Builds a dataframe containing all unique page identifiers up
    to a specified depth and counting the number of sub-pages for each.
    Prints results to a CSV file.

    urls : list
        List of page URLs.

    layers : int
        Depth of automated URL search. Large values for this parameter
        may cause long runtimes depending on the number of URLs.
    '''

    # Store results in a dataframe
    sitemap_layers = pd.DataFrame()

    # Get base levels
    bases = pd.Series([url.split('//')[-1].split('/')[0] for url in urls])
    sitemap_layers[0] = bases

    # Get specified number of layers
    for layer in range(1, layers+1):

        page_layer = []
        for url, base in zip(urls, bases):
            try:
                page_layer.append(url.split(base)[-1].split('/')[layer])
            except:
                # There is nothing that deep!
                page_layer.append('')

        sitemap_layers[layer] = page_layer

    # Count and drop duplicate rows + sort
    sitemap_layers = sitemap_layers.groupby(list(range(0, layers+1)))[0].count()\
                     .rename('counts').reset_index()\
                     .sort_values('counts', ascending=False)\
                     .sort_values(list(range(0, layers)), ascending=True)\
                     .reset_index(drop=True)
    
    # Convert column names to string types and export
    sitemap_layers.columns = [str(col) for col in sitemap_layers.columns]
    sitemap_layers.to_csv('sitemap_layers.csv', index=False)

    # Return the dataframe
    return sitemap_layers

# %% [markdown]
# The `peel_layers` function also counts the number of pages for each layer. These can be accessed by looking at the output dataframe in Python or opening the output file `sitemap_layers.csv` in Excel. Let's do this for three layers.

# %%
sitemap_layers = peel_layers(urls=urls, layers=3)
sitemap_layers
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>www.ringcentral.com</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>www.ringcentral.com</td>
#       <td>business-phone-system.html</td>
#       <td></td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>www.ringcentral.com</td>
#       <td>business-voip.html</td>
#       <td></td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>www.ringcentral.com</td>
#       <td>cloud-has-won</td>
#       <td></td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>www.ringcentral.com</td>
#       <td>cloud-pbx.html</td>
#       <td></td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>www.ringcentral.com</td>
#       <td>collaborative-communications.html</td>
#       <td></td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>www.ringcentral.com</td>
#       <td>community</td>
#       <td>index.html</td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>www.ringcentral.com</td>
#       <td>company</td>
#       <td>careers</td>
#       <td>locations.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>www.ringcentral.com</td>
#       <td>company</td>
#       <td>careers</td>
#       <td>overview.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>www.ringcentral.com</td>
#       <td>company</td>
#       <td>careers</td>
#       <td>job-listings.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>www.ringcentral.com</td>
#       <td>company</td>
#       <td>careers</td>
#       <td>internship-program.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>www.ringcentral.com</td>
#       <td>contact-center</td>
#       <td>agents.html</td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>www.ringcentral.com</td>
#       <td>contact-center</td>
#       <td>contact-center-features.html</td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>www.ringcentral.com</td>
#       <td>contact-center</td>
#       <td>faq.html</td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>www.ringcentral.com</td>
#       <td>contact-center</td>
#       <td>integrations.html</td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>www.ringcentral.com</td>
#       <td>contact-center</td>
#       <td>overview.html</td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>www.ringcentral.com</td>
#       <td>contact-center</td>
#       <td>plans-and-pricing.html</td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>www.ringcentral.com</td>
#       <td>contact-center</td>
#       <td>supervisors.html</td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>www.ringcentral.com</td>
#       <td>contact-center</td>
#       <td>workforce-optimization.html</td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>www.ringcentral.com</td>
#       <td>cpaas.html</td>
#       <td></td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>www.ringcentral.com</td>
#       <td>demo.html</td>
#       <td></td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>www.ringcentral.com</td>
#       <td>europe</td>
#       <td></td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>www.ringcentral.com</td>
#       <td>fax</td>
#       <td>features</td>
#       <td>faq.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>www.ringcentral.com</td>
#       <td>fax</td>
#       <td>features</td>
#       <td>how-it-works.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>www.ringcentral.com</td>
#       <td>fax</td>
#       <td>features</td>
#       <td>whitepaper.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>www.ringcentral.com</td>
#       <td>fax</td>
#       <td>features.html</td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>www.ringcentral.com</td>
#       <td>features</td>
#       <td>local-numbers</td>
#       <td>area-code-818.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>www.ringcentral.com</td>
#       <td>features</td>
#       <td>local-numbers</td>
#       <td>area-code-949.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>www.ringcentral.com</td>
#       <td>features</td>
#       <td>local-numbers</td>
#       <td>area-code-925.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>www.ringcentral.com</td>
#       <td>features</td>
#       <td>local-numbers</td>
#       <td>area-code-916.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>252</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>contactus.html</td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>253</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>formedia.html</td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>254</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>inthenews</td>
#       <td>inthenews-2009.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>255</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>inthenews</td>
#       <td>inthenews-2015.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>256</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>inthenews</td>
#       <td>inthenews-2014.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>257</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>inthenews</td>
#       <td>inthenews-2013.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>258</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>inthenews</td>
#       <td>inthenews-2012.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>259</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>inthenews</td>
#       <td>inthenews-2011.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>260</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>inthenews</td>
#       <td>inthenews-2010.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>261</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>inthenews</td>
#       <td>inthenews-2008.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>262</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>inthenews</td>
#       <td>inthenews-2007.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>263</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>inthenews</td>
#       <td>inthenews-2016.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>264</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>inthenews.html</td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>265</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>leadership</td>
#       <td>clyde-hosein.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>266</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>leadership</td>
#       <td>ryan-azus.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>267</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>leadership</td>
#       <td>walt-weisner.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>268</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>leadership</td>
#       <td>vlad-vendrow.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>269</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>leadership</td>
#       <td>vlad-shmunis.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>270</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>leadership</td>
#       <td>richard-borenstein.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>271</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>leadership</td>
#       <td>david-sipes.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>272</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>leadership</td>
#       <td>riadh-dridi.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>273</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>leadership</td>
#       <td>praful-k-shah.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>274</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>leadership</td>
#       <td>mitesh-dhruv.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>275</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>leadership</td>
#       <td>kira-makagon.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>276</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>leadership</td>
#       <td>john-marlow.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>277</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>leadership</td>
#       <td>derrell-james.html</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>278</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>leadership.html</td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>279</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>pressimages.html</td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>280</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral</td>
#       <td>reviews.html</td>
#       <td></td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>281</th>
#       <td>www.ringcentral.com</td>
#       <td>whyringcentral.html</td>
#       <td></td>
#       <td></td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# <p>282 rows × 5 columns</p>
# </div>

# %% [markdown]
# <img src="static/sitemap_layers_alt.png" width="700">

# %% [markdown]
# At this point you may be inclined to continue with further analysis in Excel, but we'll invite you to carry on in Python.
#
# ## Filtering
#
# The `peel_layers` function returns a [Pandas DataFrame](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html) that we stored in the variable `sitemap_layers`. This contains the exported `.csv` data as a table inside Python, and it can be filtered or otherwise modified in any way. Say, for example, we are interested in the number of pages relating to hockey. We may want to run a script like this one that searches for rows with "hockey" in the third layer:

# %%
counts = 0
for row in sitemap_layers.values:

    # Check if the word "hockey" is contained in the 3rd layer
    if 'hockey' in row[3]:
        # Add the page counts value from the outer right column
        counts += row[-1]

print('%d total hockey pages' % counts)
# Out:
# 3014 total hockey pages

# %% [markdown]
# This could also be accomplished in a single line.

# %%
counts = sitemap_layers[sitemap_layers['3'].apply(
            lambda string: 'hockey' in string)]\
            ['counts'].sum()
    
print('%d total hockey pages' % counts)
# Out:
# 3014 total hockey pages

# %% [markdown]
# What we do here is filter the dataframe (as seen below) and then sum the counts column.

# %%
sitemap_fltr = sitemap_layers[sitemap_layers['3'].apply(lambda string: 'hockey' in string)]
sitemap_fltr
# Out:
#                    0           1              2                     3  counts
# 40  www.sportchek.ca  categories      equipment                hockey    1276
# 59  www.sportchek.ca  categories       fan-shop  international-hockey     160
# 66  www.sportchek.ca  categories  shop-by-sport                hockey    1578

# %% [markdown]
# This table can be saved to an Excel readable format using the `to_csv` function.

# %%
sitemap_fltr.to_csv('hockey_pages.csv', index=False)

# %% [markdown]
# Filtering conditions can be as specific as you desire. For example if you want to find snowboard and ski pages:

# %%
sitemap_fltr = sitemap_layers[sitemap_layers['3'].apply(lambda string: 'ski' in string or\
                                                                       'snowboard' in string)]
sitemap_fltr
# Out:
#                    0           1                   2  \
# 12  www.sportchek.ca  categories  deals-and-features
# 30  www.sportchek.ca  categories  deals-and-features
# 31  www.sportchek.ca  categories  deals-and-features
# 39  www.sportchek.ca  categories         electronics
# 41  www.sportchek.ca  categories           equipment
# 42  www.sportchek.ca  categories           equipment
#
#                             3  counts
# 12  prior-snowboard-clearance     230
# 30         junior-ski-package       2
# 31   junior-snowboard-package       1
# 39         skills-development      10
# 41              alpine-skiing     700
# 42               snowboarding     621

# %% [markdown]
# Oops, it looks like "skills-development" is included as is contains "ski". Let's exclude this term.

# %%
sitemap_fltr = sitemap_layers[sitemap_layers['3'].apply(lambda string: ('ski' in string or\
                                                                        'snowboard' in string)\
                                                                        and 'skills-dev' not in string)]
sitemap_fltr
# Out:
#                    0           1                   2  \
# 12  www.sportchek.ca  categories  deals-and-features
# 30  www.sportchek.ca  categories  deals-and-features
# 31  www.sportchek.ca  categories  deals-and-features
# 41  www.sportchek.ca  categories           equipment
# 42  www.sportchek.ca  categories           equipment
#
#                             3  counts
# 12  prior-snowboard-clearance     230
# 30         junior-ski-package       2
# 31   junior-snowboard-package       1
# 41              alpine-skiing     700
# 42               snowboarding     621

# %% [markdown]
# Other useful filtering tools are the `split` and `len` functions. For instance, we could find all the pages with at least four "-" characters in the 3rd layer.

# %%
sitemap_fltr = sitemap_layers[sitemap_layers['3'].apply(lambda string: len(string.split('-')) >= 4)]
sitemap_fltr
# Out:
#                    0           1                   2  \
# 15  www.sportchek.ca  categories  deals-and-features
# 32  www.sportchek.ca  categories         electronics
#
#                               3  counts
# 15  rule-the-winter-collections     142
# 32  trackers-watches-heart-rate     200

# %% [markdown]
# In this example, we split the string into a list of substrings as separated by the dashes and check if the list has more than 3 elements.
#
# Working with Pandas DataFrames in Python can seem very complicated - especially for those new to Python - but the rewards are great.

# %% [markdown]
# ## Visualizing sitemap

# %% [markdown]
# Storing data in tables is the only reasonable option, but it's not always the best way to view the data. This is especially true when sharing it with others.
#
# The sitemap dataframe we've generated can be nicely visualized using graphviz, where paths are illustrated with nodes and edges. The nodes contain site page layers and the edges are labelled by the number of sub-pages existing within that path.

# %%
def make_sitemap_graph(df, layers=3, limit=50, size='8,5'):
    ''' Make a sitemap graph up to a specified layer depth.
    
    sitemap_layers : DataFrame
        The dataframe created by the peel_layers function 
        containing sitemap information.
    
    layers : int
        Maximum depth to plot.
        
    limit : int
        The maximum number node edge connections. Good to set this
        low for visualizing deep into site maps.
    '''
    
    
    # Check to make sure we are not trying to plot too many layers
    if layers > len(df) - 1:
        layers = len(df)-1
        print('There are only %d layers available to plot, setting layers=%d'
              % (layers, layers))
    
    
    # Initialize graph
    f = graphviz.Digraph('sitemap', filename='sitemap_graph_%d_layer' % layers)
    f.body.extend(['rankdir=LR', 'size="%s"' % size])
    
    
    def add_branch(f, names, vals, limit, connect_to=''):
        ''' Adds a set of nodes and edges to nodes on the previous layer. '''
        
        # Get the currently existing node names
        node_names = [item.split('"')[1] for item in f.body if 'label' in item]
        
        # Only add a new branch it it will connect to a previously created node
        if connect_to:
            if connect_to in node_names:
                for name, val in list(zip(names, vals))[:limit]:
                    f.node(name='%s-%s' % (connect_to, name), label=name)
                    f.edge(connect_to, '%s-%s' % (connect_to, name), label='{:,}'.format(val))
        

    f.attr('node', shape='rectangle') # Plot nodes as rectangles
    
    # Add the first layer of nodes
    for name, counts in df.groupby(['0'])['counts'].sum().reset_index()\
                          .sort_values(['counts'], ascending=False).values:
        f.node(name=name, label='{} ({:,})'.format(name, counts))
    
    if layers == 0:
        return f
    
    f.attr('node', shape='oval') # Plot nodes as ovals
    f.graph_attr.update()
    
    # Loop over each layer adding nodes and edges to prior nodes
    for i in range(1, layers+1):
        cols = [str(i_) for i_ in range(i)]
        for k in df[cols].drop_duplicates().values:
            
            # Compute the mask to select correct data
            mask = True
            for j, ki in enumerate(k):
                mask &= df[str(j)] == ki
                
            # Select the data then count branch size, sort, and truncate
            data = df[mask].groupby([str(i)])['counts'].sum()\
                    .reset_index().sort_values(['counts'], ascending=False)
                
            # Add to the graph
            add_branch(f,
                       names=data[str(i)].values,
                       vals=data['counts'].values,
                       limit=limit,
                       connect_to='-'.join(['%s']*i) % tuple(k))
            
    return f


def apply_style(f, style, title=''):
    ''' Apply the style and add a title if desired. More styling options are
    documented here: http://www.graphviz.org/doc/info/attrs.html#d:style
    
    f : graphviz.dot.Digraph
        The graph object as created by graphviz.
    
    style : str
        Available styles: 'light', 'dark'
        
    title : str
        Optional title placed at the bottom of the graph.
    '''
    
    dark_style = {
        'graph': {
            'label': title,
            'bgcolor': '#3a3a3a',
            'fontname': 'Helvetica',
            'fontsize': '18',
            'fontcolor': 'white',
        },
        'nodes': {
            'style': 'filled',
            'color': 'white',
            'fillcolor': 'black',
            'fontname': 'Helvetica',
            'fontsize': '14',
            'fontcolor': 'white',
        },
        'edges': {
            'color': 'white',
            'arrowhead': 'open',
            'fontname': 'Helvetica',
            'fontsize': '12',
            'fontcolor': 'white',
        }
    }

    light_style = {
        'graph': {
            'label': title,
            'fontname': 'Helvetica',
            'fontsize': '18',
            'fontcolor': 'black',
        },
        'nodes': {
            'style': 'filled',
            'color': 'black',
            'fillcolor': '#dbdddd',
            'fontname': 'Helvetica',
            'fontsize': '14',
            'fontcolor': 'black',
        },
        'edges': {
            'color': 'black',
            'arrowhead': 'open',
            'fontname': 'Helvetica',
            'fontsize': '12',
            'fontcolor': 'black',
        }
    }
    
    if style == 'light':
        apply_style = light_style
            
    elif style == 'dark':
        apply_style = dark_style
        
    f.graph_attr = apply_style['graph']
    f.node_attr = apply_style['nodes']
    f.edge_attr = apply_style['edges']
    
    return f

# %% [markdown]
# The code that builds and exports this visualization is contained within a function called `make_sitemap_graph` that takes in our data and the number of layers deep we wish to see. For example we can do:

# %%
f = make_sitemap_graph(sitemap_layers, layers=2)
f = apply_style(f, 'light', title='Sport Check Sitemap')
f.render(cleanup=True)
f
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\site-packages\graphviz\backend.py in render(engine, format, filepath, quiet)
#     123         try:
# --> 124             subprocess.check_call(args, startupinfo=STARTUPINFO, stderr=stderr)
#     125         except OSError as e:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\subprocess.py in check_call(*popenargs, **kwargs)
#     575     """
# --> 576     retcode = call(*popenargs, **kwargs)
#     577     if retcode:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\subprocess.py in call(timeout, *popenargs, **kwargs)
#     556     """
# --> 557     with Popen(*popenargs, **kwargs) as p:
#     558         try:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     946                                 errread, errwrite,
# --> 947                                 restore_signals, start_new_session)
#     948         except:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1223                                          cwd,
# -> 1224                                          startupinfo)
#    1225             finally:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# ExecutableNotFound                        Traceback (most recent call last)
# <ipython-input-25-ab87c524083c> in <module>()
#       1 f = make_sitemap_graph(sitemap_layers, layers=2)
#       2 f = apply_style(f, 'light', title='Sport Check Sitemap')
# ----> 3 f.render(cleanup=True)
#       4 f
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\site-packages\graphviz\files.py in render(self, filename, directory, view, cleanup)
#     173         filepath = self.save(filename, directory)
#     174
# --> 175         rendered = backend.render(self._engine, self._format, filepath)
#     176
#     177         if cleanup:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\site-packages\graphviz\backend.py in render(engine, format, filepath, quiet)
#     127                 raise ExecutableNotFound(args)
#     128             else:  # pragma: no cover
# --> 129                 raise
#     130
#     131     return rendered
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\site-packages\graphviz\backend.py in open(name, mode)
#     118         def open(name, mode):
#     119             assert name == os.devnull and mode == 'w'
# --> 120             yield None
#     121
#     122     with open(os.devnull, 'w') as stderr:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\site-packages\graphviz\backend.py in render(engine, format, filepath, quiet)
#     125         except OSError as e:
#     126             if e.errno == errno.ENOENT:
# --> 127                 raise ExecutableNotFound(args)
#     128             else:  # pragma: no cover
#     129                 raise
#
# ExecutableNotFound: failed to execute ['dot', '-Tpdf', '-O', 'sitemap_graph_2_layer'], make sure the Graphviz executables are on your systems' PATH

# %% [markdown]
# Or we can use the dark style:

# %%
f = make_sitemap_graph(sitemap_layers, layers=2)
f = apply_style(f, 'dark')
f.render(cleanup=True)
f
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\site-packages\graphviz\backend.py in render(engine, format, filepath, quiet)
#     123         try:
# --> 124             subprocess.check_call(args, startupinfo=STARTUPINFO, stderr=stderr)
#     125         except OSError as e:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\subprocess.py in check_call(*popenargs, **kwargs)
#     575     """
# --> 576     retcode = call(*popenargs, **kwargs)
#     577     if retcode:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\subprocess.py in call(timeout, *popenargs, **kwargs)
#     556     """
# --> 557     with Popen(*popenargs, **kwargs) as p:
#     558         try:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     946                                 errread, errwrite,
# --> 947                                 restore_signals, start_new_session)
#     948         except:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1223                                          cwd,
# -> 1224                                          startupinfo)
#    1225             finally:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# ExecutableNotFound                        Traceback (most recent call last)
# <ipython-input-26-5fe973c08203> in <module>()
#       1 f = make_sitemap_graph(sitemap_layers, layers=2)
#       2 f = apply_style(f, 'dark')
# ----> 3 f.render(cleanup=True)
#       4 f
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\site-packages\graphviz\files.py in render(self, filename, directory, view, cleanup)
#     173         filepath = self.save(filename, directory)
#     174
# --> 175         rendered = backend.render(self._engine, self._format, filepath)
#     176
#     177         if cleanup:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\site-packages\graphviz\backend.py in render(engine, format, filepath, quiet)
#     127                 raise ExecutableNotFound(args)
#     128             else:  # pragma: no cover
# --> 129                 raise
#     130
#     131     return rendered
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\site-packages\graphviz\backend.py in open(name, mode)
#     118         def open(name, mode):
#     119             assert name == os.devnull and mode == 'w'
# --> 120             yield None
#     121
#     122     with open(os.devnull, 'w') as stderr:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\site-packages\graphviz\backend.py in render(engine, format, filepath, quiet)
#     125         except OSError as e:
#     126             if e.errno == errno.ENOENT:
# --> 127                 raise ExecutableNotFound(args)
#     128             else:  # pragma: no cover
#     129                 raise
#
# ExecutableNotFound: failed to execute ['dot', '-Tpdf', '-O', 'sitemap_graph_2_layer'], make sure the Graphviz executables are on your systems' PATH

# %% [markdown]
# Setting `layers=3` we see that our graph is already very large! Here we set `size=35` to create a higher resolution PDF file where the details are clearly visible.

# %%
f = make_sitemap_graph(sitemap_layers, layers=3, size='35')
f = apply_style(f, 'light')
f.render(cleanup=True)
f
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\site-packages\graphviz\backend.py in render(engine, format, filepath, quiet)
#     123         try:
# --> 124             subprocess.check_call(args, startupinfo=STARTUPINFO, stderr=stderr)
#     125         except OSError as e:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\subprocess.py in check_call(*popenargs, **kwargs)
#     575     """
# --> 576     retcode = call(*popenargs, **kwargs)
#     577     if retcode:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\subprocess.py in call(timeout, *popenargs, **kwargs)
#     556     """
# --> 557     with Popen(*popenargs, **kwargs) as p:
#     558         try:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     946                                 errread, errwrite,
# --> 947                                 restore_signals, start_new_session)
#     948         except:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1223                                          cwd,
# -> 1224                                          startupinfo)
#    1225             finally:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# ExecutableNotFound                        Traceback (most recent call last)
# <ipython-input-27-ee5bf485ae5e> in <module>()
#       1 f = make_sitemap_graph(sitemap_layers, layers=3, size='35')
#       2 f = apply_style(f, 'light')
# ----> 3 f.render(cleanup=True)
#       4 f
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\site-packages\graphviz\files.py in render(self, filename, directory, view, cleanup)
#     173         filepath = self.save(filename, directory)
#     174
# --> 175         rendered = backend.render(self._engine, self._format, filepath)
#     176
#     177         if cleanup:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\site-packages\graphviz\backend.py in render(engine, format, filepath, quiet)
#     127                 raise ExecutableNotFound(args)
#     128             else:  # pragma: no cover
# --> 129                 raise
#     130
#     131     return rendered
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\site-packages\graphviz\backend.py in open(name, mode)
#     118         def open(name, mode):
#     119             assert name == os.devnull and mode == 'w'
# --> 120             yield None
#     121
#     122     with open(os.devnull, 'w') as stderr:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\site-packages\graphviz\backend.py in render(engine, format, filepath, quiet)
#     125         except OSError as e:
#     126             if e.errno == errno.ENOENT:
# --> 127                 raise ExecutableNotFound(args)
#     128             else:  # pragma: no cover
#     129                 raise
#
# ExecutableNotFound: failed to execute ['dot', '-Tpdf', '-O', 'sitemap_graph_3_layer'], make sure the Graphviz executables are on your systems' PATH

# %% [markdown]
# Another useful feature built into the graphing script is the ability to limit branch size. This can let us create deep sitemap visualizations that don't grow out of control. For example, limiting each branch to the top three (in terms of recursive page count):

# %%
sitemap_layers = peel_layers(urls=sitemap_urls, layers=5)
f = make_sitemap_graph(sitemap_layers, layers=5, limit=3, size='25')
f = apply_style(f, 'light')
f.render(cleanup=True)
f
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\site-packages\graphviz\backend.py in render(engine, format, filepath, quiet)
#     123         try:
# --> 124             subprocess.check_call(args, startupinfo=STARTUPINFO, stderr=stderr)
#     125         except OSError as e:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\subprocess.py in check_call(*popenargs, **kwargs)
#     575     """
# --> 576     retcode = call(*popenargs, **kwargs)
#     577     if retcode:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\subprocess.py in call(timeout, *popenargs, **kwargs)
#     556     """
# --> 557     with Popen(*popenargs, **kwargs) as p:
#     558         try:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     946                                 errread, errwrite,
# --> 947                                 restore_signals, start_new_session)
#     948         except:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1223                                          cwd,
# -> 1224                                          startupinfo)
#    1225             finally:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# ExecutableNotFound                        Traceback (most recent call last)
# <ipython-input-28-a928312cd778> in <module>()
#       2 f = make_sitemap_graph(sitemap_layers, layers=5, limit=3, size='25')
#       3 f = apply_style(f, 'light')
# ----> 4 f.render(cleanup=True)
#       5 f
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\site-packages\graphviz\files.py in render(self, filename, directory, view, cleanup)
#     173         filepath = self.save(filename, directory)
#     174
# --> 175         rendered = backend.render(self._engine, self._format, filepath)
#     176
#     177         if cleanup:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\site-packages\graphviz\backend.py in render(engine, format, filepath, quiet)
#     127                 raise ExecutableNotFound(args)
#     128             else:  # pragma: no cover
# --> 129                 raise
#     130
#     131     return rendered
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\site-packages\graphviz\backend.py in open(name, mode)
#     118         def open(name, mode):
#     119             assert name == os.devnull and mode == 'w'
# --> 120             yield None
#     121
#     122     with open(os.devnull, 'w') as stderr:
#
# C:\Users\pzeli\AppData\Local\Continuum\Anaconda3\lib\site-packages\graphviz\backend.py in render(engine, format, filepath, quiet)
#     125         except OSError as e:
#     126             if e.errno == errno.ENOENT:
# --> 127                 raise ExecutableNotFound(args)
#     128             else:  # pragma: no cover
#     129                 raise
#
# ExecutableNotFound: failed to execute ['dot', '-Tpdf', '-O', 'sitemap_graph_5_layer'], make sure the Graphviz executables are on your systems' PATH

# %% [markdown]
# ## Summary and Script Usage
#
# In this post we have shown how Python can be used to extract, categorize and visualize an XML sitemap. The code we looked at has been optimized for your personal use and aggregated into three Python scripts that can be downloaded here:
#
# [XML sitemap extraction tool](https://github.com/ayima)
#
# These can be leveraged to automate URL extraction, categorization and visualization for the sitemap of your choice. For usage instructions, please make sure to check out the [online source code repository](https://github.com/ayima).
#
# Thanks for reading, we hope you found this tutorial useful. If you run into any problems using our automated XML sitemap retrieval scripts we are here to help! You can reach us on twitter [@ayima](https://twitter.com/ayima).
